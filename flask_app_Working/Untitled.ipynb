# %%
from flask import Flask, render_template, request
from recommender import random_recommend
import pandas as pd
import numpy as np
from sklearn.decomposition import NMF
import pandas as pd

# %%
MOVIES = [x[:-7] for x in (pd.read_csv('movies.csv'))['title'].values.tolist()]

# %%
MOVIES
# Out:
# ['Toy Story',
#  'Jumanji',
#  'Grumpier Old Men',
#  'Waiting to Exhale',
#  'Father of the Bride Part II',
#  'Heat',
#  'Sabrina',
#  'Tom and Huck',
#  'Sudden Death',
#  'GoldenEye',
#  'American President, The',
#  'Dracula: Dead and Loving It',
#  'Balto',
#  'Nixon',
#  'Cutthroat Island',
#  'Casino',
#  'Sense and Sensibility',
#  'Four Rooms',
#  'Ace Ventura: When Nature Calls',
#  'Money Train',
#  'Get Shorty',
#  'Copycat',
#  'Assassins',
#  'Powder',
#  'Leaving Las Vegas',
#  'Othello',
#  'Now and Then',
#  'Persuasion',
#  'City of Lost Children, The (Cité des enfants perdus, La)',
#  'Shanghai Triad (Yao a yao yao dao waipo qiao)',
#  'Dangerous Minds',
#  'Twelve Monkeys (a.k.a. 12 Monkeys)',
#  'Babe',
#  'Dead Man Walking',
#  'It Takes Two',
#  'Clueless',
#  'Cry, the Beloved Country',
#  'Richard III',
#  'Dead Presidents',
#  'Restoration',
#  'Mortal Kombat',
#  'To Die For',
#  'How to Make an American Quilt',
#  'Seven (a.k.a. Se7en)',
#  'Pocahontas',
# ...

# %%
#user_input = []
user_input_movies = ['Nixon2222', 'Sabrina', 'Casino']
user_input_ratings = [3,2,4]
user_input_movies2=[]

# %%
check =  all(item in user_input_movies for item in MOVIES)

# %%
check
# Out:
# False

# %%
sum([item in user_input_movies for item in MOVIES])
# Out:
# 3

# %%
len(MOVIES)
# Out:
# 9742

# %%
movies2 = list(set(MOVIES))

# %%
len(movies2)
# Out:
# 9460

# %%
if len([True for x in user_input_movies if x in MOVIES]) == 3:
    return True
# Out:
# [True, True]

# %%
[x if x in MOVIES else 'sorry: This movie does not exist' for x in user_input_movies]
# Out:
# ['sorry: This movie does not exist', 'Sabrina', 'Casino']

# %%
userprintour = [x if x in MOVIES else 'sorry: This movie does not exist' for x in user_input_movies]
